# %% [markdown]
# # Is Staten Island more like other Boroughs of New York City?

# %% [markdown]
# ## Introduction

# %% [markdown]
# Staten Island is one of the five borough in New York City. It is coextensive with Richmond County, in the U.S. state of New York. Located in the southwest portion of the city, the borough is separated from New Jersey by the Arthur Kill and the Kill Van Kull and from the rest of New York by New York Bay. With an estimated population of 476,143 in 2019, Staten Island is the least-populated of the boroughs but is the third-largest in land area at 58.5 sq mi.

# %% [markdown]
# The North Shore—especially the neighborhoods of St. George, Tompkinsville, Clifton, and Stapleton—is the most urban part of the island. It contains the designated St. George Historic District and the St. Paul's Avenue-Stapleton Heights Historic District, which feature large Victorian houses.

# %% [markdown]
# In this project, I'm compare the Staten Island Neighborhoods and four other boroughs in New York. such as Manhattan, Bronx, Queens and Brooklyn. To find out the similarity and differences in Staten Island and other five Boroughs.This project will help the people who wants to move to Staten Island and tourist who plan to visit Staten Island. Also It helps to people who are looking for a buy a house in Staten Island.

# %% [markdown]
# ## Data Description

# %% [markdown]
# 1. I used Forsquare API to get the most common venues of five Boroughs of New York City.

# %% [markdown]
# 2. I found the Second-level Administrative Divisions of the New York City from Spatial Data Repository of NYU.json file has coordinates of the all boroughs of New York City.

# %% [markdown]
# 3. Segment and cluster the each and every boroughs neighborhoods seperatly.

# %% [markdown]
# 4. Finally compare the Staten Island neighborhoods to other neighborhoods to conclude the results.

# %% [markdown]
# ## Methodology

# %% [markdown]
# #### Download and Explore Dataset

# %% [markdown]
# Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood. I used this dataset. https://geo.nyu.edu/catalog/nyu_2451_34572

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# #### Create a map of New York with neighborhoods superimposed on top.

# %% [markdown]
# I used python folium library to visualize geographic details of New York Ciry.I used latitude and longitude values to get the visual as below:

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %% [markdown]
# then utilized the Foursquare API to explore the boroughs and segment them. for each borough create a new dataframe.
# as a ex,

# %% [markdown]
# ![3.JPG](attachment:3.JPG)

# %% [markdown]
# then visualize the borough neiborhoods in a map
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# Then Get the neighborhood's latitude and longitude values.after that get the top 100 venues that are in Marble Hill within a radius of 500 meters.![5.JPG](attachment:5.JPG)

# %% [markdown]
# #### Analyze each Neighborhood

# %% [markdown]
# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category. Then print each neighborhood along with the top 5 most common venues.
# ![6.JPG](attachment:6.JPG)

# %% [markdown]
# #### Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.Finally,visualize the resulting clusters.
# ![7.JPG](attachment:7.JPG)

# %% [markdown]
# ![8.JPG](attachment:8.JPG)
# Estimate the number of 1St most common venue in each cluster.

# %% [markdown]
# ## Results

# %% [markdown]
# In the result, I examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories.![9.JPG](attachment:9.JPG)

# %% [markdown]
# Then for better understanding plot bar chart to demonstrate 1st most common venue in each cluster.![8.JPG](attachment:8.JPG)

# %% [markdown]
# furthermore, visualize the resulting clusters in google map![7.JPG](attachment:7.JPG)

# %% [markdown]
# ## Discussion

# %% [markdown]
# As I mentioned,Staten Island is one of the five borough in New York City. It is coextensive with Richmond County, in the U.S. state of New York. Located in the southwest portion of the city, the borough is separated from New Jersey by the Arthur Kill and the Kill Van Kull and from the rest of New York by New York Bay. With an estimated population of 476,143 in 2019, Staten Island is the least-populated of the boroughs but is the third-largest in land area at 58.5 sq mi.
#     However Staten Island is the most forgotten borough in New York City. In this project try to Analyze the data of Staten Island and its neighborhood. It will help people who wants to move to Staten Island and tourist who plan to visit Staten Island. Also It helps to people who are looking for a buy a house in Staten Island.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# As a result, people are turning to big cities to start a business or work. For this reason, people can achieve better outcomes through their access to the platforms where such information is provided.Not only for investors but also city managers can manage the city more regularly by using similar data analysis types or platforms.
