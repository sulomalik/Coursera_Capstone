# %% [markdown]
# ## Data Description

# %% [markdown]
# 1. I used Forsquare API to get the most common venues of given Borough of New York City.

# %% [markdown]
# 2. I found the .json file has coordinates of the all boroughs of New York City.

# %% [markdown]
# 3. segment and cluster the each and every boroughs neighborhoods seperatly.

# %% [markdown]
# 4. Finally compare the Staten Island
